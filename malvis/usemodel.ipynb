# %%
import cv2
import tensorflow as tf

# %%
CATEGORIES = ["benign","malcious"]

# %%
def prepare(filepath):
    IMG_SIZE=200
    img_array = cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
    return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
model = tf.keras.models.load_model("CNN-model")

# %%
prediction = model.predict([prepare('testimages/other1.PNG')])
print(prediction)
print(CATEGORIES[int(prediction[0][0])])
# Out:
# [[1.]]
# malcious

# %%
import glob, os
os.chdir("testimages")

# %%
for file in glob.glob("*.PNG"):
    print(file)
    prediction = model.predict([prepare(file)])
    print(prediction)
    print(CATEGORIES[int(prediction[0][0])])
# Out:
# 7z1900_lanczos_120_.png
# [[1.]]
# malcious
# agent1.png
# [[1.]]
# malcious
# other1.png
# [[1.]]
# malcious
# other2.png
# [[1.]]
# malcious

# %%
os.chdir("F:/jeevanthask/research/datasets/malvisdataset/val/Other")

# %%
for file in glob.glob("*.PNG"):
    print(file)
    prediction = model.predict([prepare(file)])
    print(prediction)
    print(CATEGORIES[int(prediction[0][0])])
# Out:
# 002884ca-0ec2-4626-9a9c-02975e036fac--resized.png
# [[1.]]
# malcious
# 0031059b-529d-4ea5-b8c2-06db664c121f--resized.png
# [[0.]]
# benign
# 0035b7fd-aa61-4ccf-8d2f-08f2dfa6e1f5--resized.png
# [[1.]]
# malcious
# 0089cfbd-50a5-460f-a2e3-b7be67358208--resized.png
# [[0.]]
# benign
# 00b51c71abe706b53318bf9d9632f193--resized.png
# [[1.]]
# malcious
# 0137cfeb-a689-445c-98e3-3ab5bf1bc514--resized.png
# [[0.]]
# benign
# 014228e2-9223-4d38-9077-567ad2cb56b4--resized.png
# [[1.]]
# malcious
# 01589154-0ba2-400a-bf2f-81757a30cbcf--resized.png
# [[0.]]
# benign
# 019c2238-c6b2-405c-8f69-e6b221beaa5c--resized.png
# [[0.]]
# benign
# 02420278-cd7b-4f6f-8bd8-b7ab08effd7f--resized.png
# [[1.]]
# malcious
# 0250b75c-2eba-4c88-b455-f8c05efa6e9b--resized.png
# [[1.]]
# malcious
# 0259bf2d-0f2a-4395-983a-4f4046d9191d--resized.png
# [[1.]]
# malcious
# 02677363-7573-4a65-84ad-00202d47565e--resized.png
# [[1.]]
# malcious
# 0276cba99c676a2310b4a04d0f702a56--resized.png
# [[0.]]
# benign
# ...
